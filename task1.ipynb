# %%
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
#URL = "https://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"
#URL = "https://www.indeed.com/jobs?q=data+scientist+$20,000&l=New+York&start=10"
URL= "https://www.indeed.co.in/Data-Scientist-jobs-in-Hyderabad,-Telangana"
#URL = "https://www.justdial.com/Hyderabad/Orthopaedic-Doctors/nct-10345039"
#URL = "https://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"
#q=data+scientist+%2420%2C000&l=New+York&start=10"

#conducting a request of the stated URL above:
page = requests.get(URL)
#specifying a desired format of “page” using the html parser - this allows python to read the various components of the page, rather than treating it as one long string.
soup = BeautifulSoup(page.text, "html.parser")
#printing soup in a more structured tree format that makes for easier reading
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <meta content="text/html;charset=utf-8" http-equiv="content-type"/>
#   <script src="//d3fw5vlhllyvee.cloudfront.net/s/d2ae644/en_IN.js" type="text/javascript">
#   </script>
#   <link href="//d3fw5vlhllyvee.cloudfront.net/s/97464e7/jobsearch_all.css" rel="stylesheet" type="text/css"/>
#   <link href="http://www.indeed.co.in/rss?q=Data+Scientist&amp;l=Hyderabad%2C+Telangana" rel="alternate" title="Data Scientist Jobs, Recruitment in Hyderabad, Telangana" type="application/rss+xml"/>
#   <link href="/m/jobs?q=Data+Scientist&amp;l=Hyderabad%2C+Telangana" media="only screen and (max-width: 640px)" rel="alternate"/>
#   <link href="/m/jobs?q=Data+Scientist&amp;l=Hyderabad%2C+Telangana" media="handheld" rel="alternate"/>
#   <script type="text/javascript">
#    if (typeof window['closureReadyCallbacks'] == 'undefined') {
#         window['closureReadyCallbacks'] = [];
#     }
#
#     function call_when_jsall_loaded(cb) {
# ...

# %%
extract_job_title_from_result(soup)
# Out:
# ['Senior Data Science Analyst, BI',
#  'Data Scientist',
#  'Data Scientist -AI/ML - Startup',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Principal Data Scientist, Machine Learning Developer',
#  'Software Engineer, Machine Learning',
#  'Associate Data Scientist',
#  'Machine Learning Engineer',
#  'ML Engineer/ Data Scientist']

# %%
def extract_job_title_from_result(soup):
    jobs = []
    for div in soup.find_all(name="div", attrs={"class":"row"}):
          for a in div.find_all(name="a", attrs={"data-tn-element":"jobTitle"}):
                jobs.append(a["title"])
    return(jobs)
extract_job_title_from_result(soup)
# Out:
# ['Senior Data Science Analyst, BI',
#  'Data Scientist',
#  'Data Scientist -AI/ML - Startup',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Principal Data Scientist, Machine Learning Developer',
#  'Software Engineer, Machine Learning',
#  'Associate Data Scientist',
#  'Machine Learning Engineer',
#  'ML Engineer/ Data Scientist']

# %%
def extract_job_title_from_result(soup):
    jobs = []
    for a in soup.find_all(name="a", attrs={"data-tn-element":"jobTitle"}):
        jobs.append(a["title"])
    return(jobs)
extract_job_title_from_result(soup)
# Out:
# ['Senior Data Science Analyst, BI',
#  'Data Scientist',
#  'Data Scientist -AI/ML - Startup',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Principal Data Scientist, Machine Learning Developer',
#  'Software Engineer, Machine Learning',
#  'Associate Data Scientist',
#  'Machine Learning Engineer',
#  'ML Engineer/ Data Scientist']

# %%
a=soup.find_all(name="a", attrs={"data-tn-element":"jobTitle"})
a
# Out:
# [<a class="jobtitle turnstileLink " data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0DHV0xOGfKyxZdaIWEMhVfglVvIGGwVRGApjtKDwSvHc2HWLJgKnfVgqDBBoxcgkoI3C0QgscllADGu37aeo3Zhvw0kJXZETCEVNn_0CyBJODcLOoZzoTYuqzIAHGnnx4DH-1U2g9hhH6itYMiXN7GZuk7-FMkFCEWotOpOlY12-51ZsOKtEXG-7ncXWN_hJvzHdM1BXk4NWmRnQHTy5Xp2Tm1oWtWkTuJ-HetIOvYckY-ul_88-1PAMYuMOK6q_9ht416isNy-pKgx7Gq0QWQvtoF1oxY-LejRKTR28yvtNpDAbin7N1kvERokVXf1FxI0BdrQ9O3YxFXY6tL2XktwYJx2QuDlYSLIBVyGj-Fvqa8QBYZVKENqovCjjdEb0KxSwo_goQjTC4Ct-PwLpjyVCR2VKJ19DbKonDhISHrlcOwr1-PODzkG1Kw8Cg-ZAFxbopUwq6X7dRyiOlpFc5nLQAacUKifLchGYlXjw7WmcNyZTIUh5tlXeuxPnZHXUnIJ5rQOAP-2F_mhTs9MARn9G8QqIu9ZfvkSrr7P8vQx1sOq-T1dxybTLPD7Zw7x5bSQ-H5DYndXJULxYbRMn7SWuwoZixYhpXw8RRdQMKOHpKKVntFrNAgeS9TUW-ERr4Yml1PRDiiKOt19GEJcKOc0mlMyG-rosnvU_zG_CuwHRHyIdK8GEI6JvfRZD5eau7oO1YAyVT6SSW9QP66uxI1uffNqeaZQb_rmcoHxHKEJ_vDqPHQZzADVwXtHuXJabyrQEoDtho4lcBXVLzx8CganQLGO8zjaCdh1Hpydk5jJUoT0fI_qCdj4WThs1Hwx77deTOAnAB0Yn3ORYBkHbJdc4JmN9XvcLosNfBtRZ9WcC5ghjRZEz2phA-XlYGKLn
# ...

# %%
def extract_company_from_result(soup): 
    companies = []
    for div in soup.find_all(name="div", attrs={"class":"row"}):
            company = div.find_all(name="span", attrs={"class":"company"})
            if len(company) > 0:
                for b in company:
                    companies.append(b.text.strip())
            else:
                sec_try = div.find_all(name="span", attrs={"class":"result-link-source"})
                for span in sec_try:
                    companies.append(span.text.strip())
    return(companies)
 
extract_company_from_result(soup)
# Out:
# ['CommScope',
#  'Maximus Human Resources',
#  'Anblicks',
#  'Julien Innovations India Pvt Ltd',
#  'IBM',
#  'Aristocrat IT Solutions Pvt Ltd.',
#  '[x]cube LABS',
#  'DELL',
#  'JDA Software',
#  'team247 infomatics pvt.Ltd',
#  'Microsoft',
#  'Microsoft']

# %%
def extract_location_from_result(soup):
    locations = []
    spans = soup.findAll("span", attrs={"class": "location"})
    for span in spans:
        locations.append(span.text)
    return(locations)
extract_location_from_result(soup)
# Out:
# ['Hyderabad, Telangana',
#  'Hyderabad, Telangana',
#  'Hyderabad, Telangana',
#  'Hyderabad, Telangana',
#  'Hyderabad, Telangana',
#  'Hyderabad, Telangana',
#  'Hyderabad, Telangana',
#  'Hyderabad, Telangana',
#  'Hyderabad, Telangana',
#  'Hyderabad, Telangana']

# %%
def extract_salary_from_result(soup): 
    salaries = []
    for div in soup.find_all(name="div", attrs={"class":"row"}):
        try:
              salaries.append(div.find("nobr").text)
        except:
            try:
                div_two = div.find(name="div", attrs={"class":"sjcl"})
                div_three = div_two.find("div")
                salaries.append(div_three.text.strip())
            except:
                salaries.append("Nothing_found")
    return(salaries)
extract_salary_from_result(soup)
# Out:
# ['CommScope\n\n\n183 reviews',
#  'Maximus Human Resources',
#  'Anblicks\n\n\n3 reviews',
#  'Julien Innovations India Pvt Ltd',
#  'IBM\n\n\n25,169 reviews',
#  'Aristocrat IT Solutions Pvt Ltd.',
#  '[x]cube LABS',
#  'DELL\n\n\n9,196 reviews',
#  'JDA Software\n\n\n184 reviews',
#  'team247 infomatics pvt.Ltd',
#  'Microsoft\n\n\n5,610 reviews',
#  'Microsoft\n\n\n5,610 reviews']

# %%
def extract_summary_from_result(soup): 
    summaries = []
    spans = soup.findAll("span", attrs={"class":"summary"})
    for span in spans:
        summaries.append(span.text.strip())
    return(summaries)

extract_summary_from_result(soup)
# Out:
# []

# %%
max_results_per_city = 100
city_set = ['New+York']
columns = ['city', 'job_title', 'company_name', 'location', 'summary', 'salary']
sample_df = pd.DataFrame(columns = columns)
sample_df
# Out:
# Empty DataFrame
# Columns: [city, job_title, company_name, location, summary, salary]
# Index: []

# %%
for city in city_set:
    for start in range(0, max_results_per_city, 10):
        page = requests.get("http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=" + str(city) + "&start=" + str(start))
        #page = requests.get("https://www.indeed.co.in/Data-Scientist-jobs-in-Hyderabad,-Telangana" + str(city) + "&start=" + str(start))
        time.sleep(1)  #ensuring at least 1 second between page grabs
        soup = BeautifulSoup(page.text, "lxml", from_encoding="utf-8")
        for div in soup.find_all(name="div", attrs={"class":"row"}): 
            num = (len(sample_df) + 1) 
            job_post = [] 
            job_post.append(city) 
            for a in div.find_all(name="a", attrs={"data-tn-element":"jobTitle"}):
                job_post.append(a["title"]) 
                company = div.find_all(name="span", attrs={"class":"company"}) 
                if len(company) > 0: 
                    for b in company:
                        job_post.append(b.text.strip())
                else:
                    sec_try = div.find_all(name="span", attrs={"class":"result-link-source"})
                    for span in sec_try:
                        job_post.append(span.text)
                        c = div.findAll('span', attrs={'class': 'location'})
                        for span in c:
                            job_post.append(span.text)
                            d = div.findAll('span', attrs={'class': 'summary'})
                            for span in d:
                                job_post.append(span.text.strip())
                                try:
                                    job_post.append(div.find('nobr').text)
                                except:
                                    try:
                                        div_two = div.find(name='div', attrs={'class':'sjcl'})
                                        div_three = div_two.find('div')
                                        job_post.append(div_three.text.strip())
                                    except:
                                        job_post.append('Nothing_found')
                                        sample_df.loc[num] = job_post
            
            
sample_df.to_csv('/home/iesoft/newfile1.csv',encoding='utf-8')
# Out:
# /home/iesoft/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:179: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")

# %%
for city in city_set:
    for start in range(0, max_results_per_city, 10):
        page = requests.get("http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=" + str(city) + "&start=" + str(start))
        #page = requests.get("https://www.indeed.co.in/Data-Scientist-jobs-in-Hyderabad,-Telangana" + str(city) + "&start=" + str(start))
        time.sleep(1)  #ensuring at least 1 second between page grabs
        soup = BeautifulSoup(page.text, "lxml", from_encoding="utf-8")
        for div in soup.find_all(name="div", attrs={"class":"row"}): 
            num = (len(sample_df) + 1) 
            job_post = [] 
            job_post.append(city) 
            for a in div.find_all(name="a", attrs={"data-tn-element":"jobTitle"}):
                job_post.append(a["title"]) 
                company = div.find_all(name="span", attrs={"class":"company"}) 
            if len(company) > 0: 
                for b in company:
                    job_post.append(b.text.strip())
            else:
                sec_try = div.find_all(name="span", attrs={"class":"result-link-source"})
                for span in sec_try:
                    job_post.append(span.text)
                    c = div.findAll('span', attrs={'class': 'location'})
                    for span in c:
                        job_post.append(span.text)
                        d = div.findAll('span', attrs={'class': 'summary'})
                    for span in d:
                        job_post.append(span.text.strip())
                    try:
                        job_post.append(div.find('nobr').text)
                    except:
                        try:
                            div_two = div.find(name='div', attrs={'class':'sjcl'})
                            div_three = div_two.find('div')
                            job_post.append(div_three.text.strip())
                        except:
                            job_post.append('Nothing_found')
                            sample_df.loc[num] = job_post
            
            
sample_df.to_csv('/home/iesoft/newfile1.csv',encoding='utf-8')

# %%
import os

# %%
job_post

# %%
sample_df
# Out:
# Empty DataFrame
# Columns: [city, job_title, company_name, location, summary, salary]
# Index: []

# %%
sample_df.to_csv('/home/iesoft/newfile.csv', sep='\t', encoding='utf-8')
